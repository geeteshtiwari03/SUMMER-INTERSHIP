# %%
name = "GEETESH TIWARI"
age = 20
city = "Jaipur"

print(name, age, city)
# Out:
# GEETESH TIWARI 20 Jaipur

# %%
print("2026","07","30",sep = '-')
# Out:
# 2026-07-30

# %%
print("A","B","C", sep ='*')
# Out:
# A*B*C

# %%
print("python","pandas","numpy", sep = '|')
# Out:
# python|pandas|numpy

# %%
print("Helllo",end = ' -> ')
print("World")
# Out:
# Helllo -> World

# %%
print("2026","05","27",sep ="*",end=' ')
print("World")
# Out:
# 2026*05*27 World

# %%
for i in range(5):
    print(i,end=" ")
# Out:
# 0 1 2 3 4

# %%
print("Name", "Age", "City", sep="\t")
print("Aman", 21, "Delhi", sep="\t")
print("Riya", 20, "Jaipur", sep="\t")
# Out:
# Name	Age	City
# Aman	21	Delhi
# Riya	20	Jaipur

# %%
name  = input("Enter your name: ")
print("Hello", name + "!", "Welcome!")
# Out:
# Hello 12! Welcome!

# %%
name = input("Enter your name: ")

print(f"Hello {name}! Welcome!")
# Out:
# Hello 1! Welcome!
